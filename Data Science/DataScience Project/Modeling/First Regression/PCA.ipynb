# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()


# %matplotlib inline


from sklearn.decomposition import PCA

# %%
# Load your data into a DataFrame
data = pd.read_csv('DataTableToRegress.csv')
features = ['C', 'Al', 'Cu', 'Fe', 'Mn', 'Ni', 'Ti', 'V', 'Cr', 'Mo', 'Nb', 'Zr']

# %%
# Assume 'target_column' is the name of your target variable
X = pd.DataFrame(data[features], columns=features)  # Features

# Assume 'target_column' is the name of your target variable
ylog = data['Acceptable']  # Target variable

# %%
pca = PCA().fit(X)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %%
pca = PCA(n_components=6)
pca.fit(X)
X_pca = pca.transform(X)
print("original shape:   ", X.shape)
print("transformed shape:", X_pca.shape)
# Out:
# original shape:    (1653, 12)
# transformed shape: (1653, 6)

# %%
# Load your data into a DataFrame
data = pd.read_csv('DataTableToRegress.csv')
features = ['C', 'Al', 'Cu', 'Fe', 'Mn', 'Ni', 'Ti', 'V', 'Cr', 'Mo', 'Nb', 'Zr']

# Assume 'target_column' is the name of your target variable
X = pd.DataFrame(data[features], columns=features)  # Features

# Assume 'target_column' is the name of your target variable
ylin = data['Tot Vol Frac Other']  # Target variable

# %%
pca = PCA().fit(X)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');
